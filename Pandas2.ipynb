# %% [markdown]
# <a href="https://colab.research.google.com/github/GeremiccaAndrea/Pandas_Ordinato/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# Visualizzare la somma dei Audience Score %

# %%
movies["Audience score %"].sum()
# Out:
# 4907

# %% [markdown]
# Visualizzare la media dei Rottem Tomatoes %

# %%
movies["Rotten Tomatoes %"].mean()
# Out:
# 46.701298701298704

# %% [markdown]
# Visualizzare i nomi dei film che sono prodotti dalla universal

# %%
movies[movies["Lead Studio"] == "Universal"][["Film"]]
# Out:
#                 Film
# 45        Mamma Mia!
# 46        Mamma Mia!
# 48      Love Happens
# 53         Leap Year
# 54        Knocked Up
# 57         Jane Eyre
# 58  It's Complicated
# 73     A Serious Man

# %% [markdown]
# Visualizzare i film e la casa produttrice che hanno un Rotten Tomatoes % superiore alla media

# %%
movies[movies["Rotten Tomatoes %"] > movies["Rotten Tomatoes %"].mean()][["Film", "Lead Studio"]]
# Out:
#                                    Film            Lead Studio
# 0            Zack and Miri Make a Porno  The Weinstein Company
# 1                       Youth in Revolt  The Weinstein Company
# 5                   Water For Elephants       20th Century Fox
# 6                                WALL-E                 Disney
# 7                              Waitress            Independent
# 12                             Twilight                 Summit
# 17               The Invention of Lying           Warner Bros.
# 19                          The Duchess              Paramount
# 20  The Curious Case of Benjamin Button           Warner Bros.
# 22                              Tangled                 Disney
# 24               She's Out of My League              Paramount
# 27                     Sex and the City           Warner Bros.
# 29               Rachel Getting Married            Independent
# 30                             Penelope                 Summit
# ...

# %% [markdown]
# Visualizzare il film con l'audience score maggiore

# %%
movies[movies["Audience score %"] == movies["Audience score %"].max()][["Film"]]
# Out:
#                   Film
# 6               WALL-E
# 74  A Dangerous Method

# %% [markdown]
# Visualizzare il minimo della colonna gross

# %%
movies["Worldwide Gross"].min()
# Out:
# '$0.03 '
