# %% [markdown]
# <a href="https://colab.research.google.com/github/GeremiccaAndrea/Pandas_Ordinato/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Pandas/winemag-data-130k-v2.json')
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         points                                              title  \
# 0           87                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1           87      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           87      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3           87  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           87  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# ...        ...                                                ...
# 129966      90  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967      90                  Citation 2004 Pinot Noir (Oregon)
# 129968      90  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969      90      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970      90  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# ...

# %% [markdown]
# contare il numero di vini italiani presenti nel datafrane

# %%
df[df["country"] == "Italy"]["country"].count()
# Out:
# 19540

# %% [markdown]
# visualizzare i vini di cui non si conosce il prezzo

# %%
df[df.price.isnull()][["title"]]
# Out:
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 13                 Masseria Setteporte 2012 Rosso  (Etna)
# 30      Domaine de la Madone 2012 Nouveau  (Beaujolais...
# 31      Duca di Salaparuta 2010 Calanìca Nero d'Avola-...
# 32      Duca di Salaparuta 2011 Calanìca Grillo-Viogni...
# ...                                                   ...
# 129844  Caparzo 2006 Doga delle Clavule  (Morellino di...
# 129860  Quinta da Pacheca 2013 Pacheca Superior Red (D...
# 129863                    Seacampo 2011 Reserva Red (Dão)
# 129893   Le Mandolare 2015 Corte Menini  (Soave Classico)
# 129964  Domaine Ehrhart 2013 Domaine Saint-Rémy Herren...
#
# [8996 rows x 1 columns]

# %% [markdown]
# visualizzare i vini che hanno le parole 'tropical fruit' nella descrizione

# %%
df[df["description"].str.contains("tropical fruit")][["title"]]
# Out:
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 34           Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# 43         Robert Hall 2011 Sauvignon Blanc (Paso Robles)
# 139     Kuentz-Bas 2007 Cuvée Jerémy Sélection de Grai...
# 151     Herdade Grande 2014 Gerações Colheita Seleccio...
# ...                                                   ...
# 129732                 Abeja 2015 Chardonnay (Washington)
# 129779     Chalk Hill 2010 Estate Chardonnay (Chalk Hill)
# 129783         Lone Birch 2011 Pinot Gris (Yakima Valley)
# 129916  Winkler-Hermaden 2006 Grauburgunder Reserve Gr...
# 129922  Sattlerhof 2006 Kranachberg Sauvignon Blanc (S...
#
# [2291 rows x 1 columns]

# %% [markdown]
# # Es2

# %%
movies = pd.read_csv('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# trovare i film che cominciano con la t

# %%
movies[movies["Film"].str.startswith("T")]
# Out:
#                                    Film      Genre   Lead Studio  \
# 10  Tyler Perry's Why Did I get Married    Romance   Independent
# 11              Twilight: Breaking Dawn    Romance   Independent
# 12                             Twilight    Romance        Summit
# 13                       The Ugly Truth     Comedy   Independent
# 14          The Twilight Saga: New Moon      Drama        Summit
# 15             The Time Traveler's Wife      Drama     Paramount
# 16                         The Proposal     Comedy        Disney
# 17               The Invention of Lying     Comedy  Warner Bros.
# 18                   The Heartbreak Kid     Comedy     Paramount
# 19                          The Duchess      Drama     Paramount
# 20  The Curious Case of Benjamin Button    Fantasy  Warner Bros.
# 21                     The Back-up Plan     Comedy           CBS
# 22                              Tangled  Animation        Disney
#
# ...

# %% [markdown]
# trovare i film che finiscono in on

# %%
movies[movies["Film"].str.endswith("on")]
# Out:
#                                    Film    Genre   Lead Studio  \
# 14          The Twilight Saga: New Moon    Drama        Summit
# 20  The Curious Case of Benjamin Button  Fantasy  Warner Bros.
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 14                78      14.196400                 27        $709.82   2009
# 20                81       1.783944                 73        $285.43   2008

# %% [markdown]
# visualizzare i titoli dei film in ordine alfabetico

# %%
movies.sort_values(by=['Film'])
# Out:
#                                   Film    Genre            Lead Studio  \
# 76                (500) Days of Summer   comedy                    Fox
# 75                          27 Dresses   Comedy                    Fox
# 74                  A Dangerous Method    Drama            Independent
# 73                       A Serious Man    Drama              Universal
# 72                 Across the Universe  romance            Independent
# ..                                 ...      ...                    ...
# 4                What Happens in Vegas   Comedy                    Fox
# 3                         When in Rome   Comedy                 Disney
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# visualizzare i titoli dei film da z-a

# %%
movies.sort_values(by=["Film"], ascending = False)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...
