# %% [markdown]
# <a href="https://colab.research.google.com/github/GeremiccaAndrea/Pandas_Ordinato/blob/main/PandasGroupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
film = pd.read_csv("https://raw.githubusercontent.com/wtitze/3E/main/2010.csv", delimiter=";")
film
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %% [markdown]
# visualizzare il numero di film per ogni lingua. Ordinare in ordine decrescente sul numero di film

# %%
film.groupby("Language")[["Title"]].count().sort_values(by="Title")
# Out:
#             Title
# Language
# Korean          1
# Tamil           1
# Swahili         1
# Slovenian       1
# Romanian        1
# Panjabi         1
# None            1
# Telugu          1
# Kannada         1
# Urdu            1
# Bosnian         1
# Danish          1
# Icelandic       2
# Swedish         2
# Norwegian       2
# Persian         2
# Indonesian      2
# Arabic          2
# Hebrew          3
# Portuguese      3
# Chinese         3
# Cantonese       3
# Italian         3
# German          3
# Polish          4
# Japanese        6
# Russian         6
# Mandarin        9
# Hindi          11
# Spanish        16
# French         24
# English      1481

# %% [markdown]
# il numero di film per ogni nazione.

# %%
film.groupby("Country")[["Country"]].count()
# Out:
#                       Country
# Country
# Australia                  18
# Bahamas                     1
# Belgium                     4
# Brazil                      3
# Bulgaria                    1
# Cambodia                    1
# Canada                     44
# Chile                       1
# China                      15
# Czech Republic              1
# Denmark                     4
# Dominican Republic          1
# Egypt                       1
# Finland                     1
# France                     54
# Georgia                     1
# Germany                    12
# Greece                      1
# Hong Kong                   3
# Hungary                     1
# Iceland                     2
# India                      16
# Indonesia                   1
# Iran                        1
# Ireland                     4
# Israel                      2
# Italy                       6
# Japan                       8
# Kenya                       1
# ...

# %% [markdown]
# il budget totale che ogni nazione ha investito nei film. Ordinare in ordine decrescente base al budget totale

# %%
filmgroup = film.groupby("Country")[["Budget"]].sum().reset_index().sort_values(by="Budget", ascending = False)
filmgroup
# Out:
#                  Country        Budget
# 49                   USA  4.592011e+10
# 48                    UK  3.618860e+09
# 14                France  9.207000e+08
# 21                 India  7.931937e+08
# 0              Australia  7.515000e+08
# 8                  China  4.900050e+08
# 16               Germany  3.901100e+08
# 6                 Canada  3.172000e+08
# 31           New Zealand  3.028500e+08
# 27                 Japan  1.575000e+08
# 43                 Spain  1.500000e+08
# 39                Russia  1.190000e+08
# 33                Norway  9.080000e+07
# 41          South Africa  8.400000e+07
# 18             Hong Kong  8.160000e+07
# 42           South Korea  7.522000e+07
# 30                Mexico  6.781878e+07
# 9         Czech Republic  5.000000e+07
# 2                Belgium  4.900000e+07
# 24               Ireland  4.200000e+07
# 26                 Italy  3.880000e+07
# 45           Switzerland  3.000000e+07
# 7                  Chile  2.600000e+07
# ...

# %% [markdown]
# il numero di film per ogni regista

# %%
directorgroup = film.groupby("Director")[["Title"]].count().reset_index()
directorgroup
# Out:
#             Director  Title
# 0         Aaron Hann      1
# 1       Adam Carolla      1
# 2         Adam McKay      3
# 3        Adam Rifkin      1
# 4      Adam Shankman      1
# ...              ...    ...
# 1087       Zack Ward      1
# 1088   Zackary Adler      1
# 1089  Zal Batmanglij      2
# 1090   Zoran Lisinac      1
# 1091   Étienne Faure      1
#
# [1092 rows x 2 columns]

# %% [markdown]
# il regista che ha diretto più film

# %%
directorgroup[directorgroup["Title"] == directorgroup["Title"].max()][["Director"]]
# Out:
#          Director
# 852  Ridley Scott

# %% [markdown]
# il numero di film per ogni genere

# %%
film.groupby("Genres")[["Title"]].count().reset_index()
# Out:
#                                                 Genres  Title
# 0                                               Action      6
# 1                                     Action|Adventure      3
# 2    Action|Adventure|Animation|Comedy|Drama|Family...      1
# 3    Action|Adventure|Animation|Comedy|Drama|Family...      1
# 4             Action|Adventure|Animation|Comedy|Family      3
# ..                                                 ...    ...
# 447                            Romance|Sci-Fi|Thriller      1
# 448                                             Sci-Fi      1
# 449                                    Sci-Fi|Thriller      4
# 450                                           Thriller     11
# 451                                            Western      2
#
# [452 rows x 2 columns]
